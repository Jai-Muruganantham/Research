# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
from glob import glob
from PIL import Image
from torchvision import transforms
import matplotlib.pyplot as plt

# Data Loading and Visualization
def load_image(image_path, size):
    transform = transforms.Compose([
        transforms.Resize((size, size)),
        transforms.ToTensor()
    ])
    image = Image.open(image_path).convert('RGB')  # Ensure 3 channels even for grayscale
    return transform(image)

def load_images(image_paths, size, mask=False, trim=None):
    if trim is not None:
        image_paths = image_paths[:trim]

    images = []
    for image_path in image_paths:
        img = load_image(image_path, size)
        if mask:
            img = img[:1, :, :]  # Take only the first channel for masks
        images.append(img)

    return torch.stack(images)

def show_image(image, title=None, cmap=None, alpha=1):
    # Convert tensor to numpy and adjust channels if necessary
    image = image.permute(1, 2, 0).numpy()  
    if image.shape[-1] == 1:
        image = image[:, :, 0]  # Grayscale
    plt.imshow(image, cmap=cmap, alpha=alpha)
    if title is not None:
        plt.title(title)
    plt.axis('off')

def show_mask(image, mask, cmap=None, alpha=0.4):
    plt.imshow(image.permute(1, 2, 0).numpy())
    plt.imshow(mask.squeeze().numpy(), cmap=cmap, alpha=alpha)
    plt.axis('off')

# Data Preparation
SIZE = 256
root_path = 'C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/'
classes = sorted(os.listdir(root_path))

single_mask_paths = sorted([sorted(glob(root_path + name + "/*mask.png")) for name in classes])
double_mask_paths = sorted([sorted(glob(root_path + name + "/*mask_1.png")) for name in classes])

image_paths = []
mask_paths = []
for class_path in single_mask_paths:
    for path in class_path:
        img_path = path.replace('_mask','')
        image_paths.append(img_path)
        mask_paths.append(path)

# Load images and masks
images = load_images(image_paths, SIZE)
masks = load_images(mask_paths, SIZE, mask=True)

# ... (rest of your data visualization and preprocessing code)

# Model Definition
class EncoderBlock(nn.Module):
    def __init__(self, in_channels, out_channels, dropout_rate=0.1, pooling=True):
        super(EncoderBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        self.dropout = nn.Dropout2d(dropout_rate)
        self.pool = nn.MaxPool2d(2) if pooling else nn.Identity()

    def forward(self, x):
        x = self.conv1(x)
        x = self.relu(x)
        x = self.conv2(x)
        x = self.relu(x)
        x = self.dropout(x)
        pooled_x = self.pool(x)
        return pooled_x, x

class DecoderBlock(nn.Module):
    def __init__(self, in_channels, out_channels, dropout_rate=0.1):
        super(DecoderBlock, self).__init__()
        self.up = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=2, stride=2)
        self.conv_block = EncoderBlock(in_channels, out_channels, dropout_rate, pooling=False)

    def forward(self, x):
        x, skip_connection = x  # Unpack the tuple
        x = self.up(x)
        x = torch.cat([x, skip_connection], dim=1) 
        x = self.conv_block(x)  # Pass the concatenated tensor
        return x[1]  # Return only the second tensor from the tuple

class AttentionGate(nn.Module):
    def __init__(self, in_channels, gating_channels, inter_channels=None, use_batchnorm=True):
        super(AttentionGate, self).__init__()
        self.use_batchnorm = use_batchnorm

        if inter_channels is None:
            inter_channels = in_channels // 2

        self.theta_conv = nn.Conv2d(in_channels, inter_channels, kernel_size=2, stride=2, bias=False)
        self.phi_conv = nn.Conv2d(gating_channels, inter_channels, kernel_size=1, bias=False)
        self.psi_conv = nn.Conv2d(inter_channels, 1, kernel_size=1, bias=False)
        self.upsample = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        self.batchnorm = nn.BatchNorm2d(gating_channels)

    def forward(self, x):
        # Encoder
        enc1, skip1 = self.encoder1(x)
        enc2, skip2 = self.encoder2(enc1)
        enc3, skip3 = self.encoder3(enc2)
        enc4, skip4 = self.encoder4(enc3)

        # Bottleneck
        bottleneck = self.bottleneck(enc4)

        # Decoder with Attention Gates
        # Extract the tensor from the skip connection tuple
        attn1 = self.attn1(bottleneck, skip4[1])  # Use skip4[1] instead of skip4
        dec1 = self.decoder1(bottleneck, attn1)
        attn2 = self.attn2(dec1, skip3[1])
        dec2 = self.decoder2(dec1, attn2)
        attn3 = self.attn3(dec2, skip2[1])
        dec3 = self.decoder3(dec2, attn3)
        attn4 = self.attn4(dec3, skip1[1])
        dec4 = self.decoder4(dec3, attn4)

        # Output
        output = self.output_conv(dec4)
        output = self.sigmoid(output)
        return output
        
# U-Net with Attention Gates
class AttentionUNet(nn.Module):
    def __init__(self, in_channels=3, out_channels=1):
        super(AttentionUNet, self).__init__()

        # Encoder
        self.encoder1 = EncoderBlock(in_channels, 32)
        self.encoder2 = EncoderBlock(32, 64)
        self.encoder3 = EncoderBlock(64, 128)
        self.encoder4 = EncoderBlock(128, 256)

        # Bottleneck
        self.bottleneck = EncoderBlock(256, 512, pooling=False)

        # Decoder with Attention Gates
        self.attn1 = AttentionGate(512, 256)
        self.decoder1 = DecoderBlock(512, 256)
        self.attn2 = AttentionGate(256, 128)
        self.decoder2 = DecoderBlock(256, 128)
        self.attn3 = AttentionGate(128, 64)
        self.decoder3 = DecoderBlock(128, 64)
        self.attn4 = AttentionGate(64, 32)
        self.decoder4 = DecoderBlock(64, 32)

        # Output
        self.output_conv = nn.Conv2d(32, out_channels, kernel_size=1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        # Encoder
        enc1, skip1 = self.encoder1(x)
        enc2, skip2 = self.encoder2(enc1)
        enc3, skip3 = self.encoder3(enc2)
        enc4, skip4 = self.encoder4(enc3)

        # Bottleneck
        bottleneck = self.bottleneck(enc4)

        # Decoder with Attention Gates
        attn1 = self.attn1(bottleneck, skip4[1])  
        dec1 = self.decoder1((bottleneck, attn1))  # Pass as a tuple
        attn2 = self.attn2(dec1, skip3[1])
        dec2 = self.decoder2((dec1, attn2))
        attn3 = self.attn3(dec2, skip2[1])
        dec3 = self.decoder3((dec2, attn3)) 
        attn4 = self.attn4(dec3, skip1[1])
        dec4 = self.decoder4((dec3, attn4))

        # Output
        output = self.output_conv(dec4)
        output = self.sigmoid(output)
        return output

# Model Instantiation and Training
model = AttentionUNet()

# Loss and Optimizer
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters())
# Define num_epochs
num_epochs = 50
batch_size = 8

# Training Loop
for epoch in range(num_epochs): 
    for i in range(0, len(images), batch_size):
        # Get a batch of images and masks
        image_batch = images[i:i+batch_size]
        mask_batch = masks[i:i+batch_size]

        optimizer.zero_grad()
        output = model(image_batch)
        loss = criterion(output, mask_batch)
        loss.backward()
        optimizer.step()

        # ... (Add validation and logging as needed)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 214
#     211 mask_batch = masks[i:i+batch_size]
#     213 optimizer.zero_grad()
# --> 214 output = model(image_batch)
#     215 loss = criterion(output, mask_batch)
#     216 loss.backward()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# Cell In[6], line 182, in AttentionUNet.forward(self, x)
#     179 bottleneck = self.bottleneck(enc4)
#     181 # Decoder with Attention Gates
# --> 182 attn1 = self.attn1(bottleneck, skip4[1])
#     183 dec1 = self.decoder1((bottleneck, attn1))  # Pass as a tuple
#     184 attn2 = self.attn2(dec1, skip3[1])
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# TypeError: AttentionGate.forward() takes 2 positional arguments but 3 were given

# %%
        # ... (Add validation and logging as needed)

# Model Saving
torch.save(model.state_dict(), 'model-regularization.pth')

# Model Loading
model = AttentionUNet()
model.load_state_dict(torch.load('model-regularization.pth'))
model.eval()  # Set to evaluation mode

# ... (Rest of your evaluation and visualization code)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

# Data Loading Functions
def load_image(image_path, SIZE):
    try:
        image = load_img(image_path)  # Load image
        image = img_to_array(image)   # Convert to numpy array
        image = image / 255.0         # Normalize the image
        image = tfi.resize(image, (SIZE, SIZE))  # Resize image
        return np.round(image, 4)     # Round to 4 decimal places
    except Exception as e:
        print(f"Error loading image {image_path}: {e}")
        return None  # Handle error

def load_images(image_paths, SIZE, mask=False):
    images = []
    for image_path in image_paths:
        image = load_image(image_path, SIZE)
        if image is not None:
            if mask:
                image = image[:, :, :1]  # Take only 1 channel for masks
            images.append(image)
    return np.array(images)

def show_image(image, title=None, cmap=None, alpha=1):
    plt.imshow(image, cmap=cmap, alpha=alpha)
    if title:
        plt.title(title)
    plt.axis('off')

def show_mask(image, mask, cmap=None, alpha=0.4):
    plt.imshow(image)
    plt.imshow(mask.squeeze(), cmap=cmap, alpha=alpha)
    plt.axis('off')

SIZE = 256
root_path = 'C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/'

# Collect image and mask paths
classes = sorted(glob(root_path + '*'))

import os

if not os.path.exists(root_path):
    print(f"Directory {root_path} does not exist.")
else:
    print(f"Directory {root_path} exists.")

classes = sorted(os.listdir(root_path))
print(f"Classes (Subdirectories): {classes}")

for class_name in classes:
    print(f"Contents of {class_name} folder: {os.listdir(os.path.join(root_path, class_name))[:5]}")

single_mask_paths = sorted([sorted(glob(root_path + name + "/*mask.png")) for name in classes])
double_mask_paths = sorted([sorted(glob(root_path + name + "/*mask_1.png")) for name in classes])

image_paths = []
mask_paths = []
for class_path in single_mask_paths:
    for path in class_path:
        img_path = path.replace('_mask', '')
        image_paths.append(img_path)
        mask_paths.append(path)

images = load_images(image_paths, SIZE)
masks = load_images(mask_paths, SIZE, mask=True)

print(f"Image Paths: {image_paths[:5]}")  # Print first 5 image paths
print(f"Mask Paths: {mask_paths[:5]}")    # Print first 5 mask paths

# PyTorch Dataset and DataLoader

class BreastCancerDataset(Dataset):
    def __init__(self, images, masks, transform=None):
        self.images = images
        self.masks = masks
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        mask = self.masks[idx]
        
        if self.transform:
            augmented = self.transform(image=image, mask=mask)
            image = augmented['image']
            mask = augmented['mask']
        
        return image, mask


# Define Transform
transform = transforms.Compose([
    transforms.ToTensor()
])

# PyTorch Dataset and DataLoader
dataset = BreastCancerDataset(images, masks, transform=transform)
print(f"Number of samples in dataset: {len(dataset)}")

dataloader = DataLoader(dataset, batch_size=8, shuffle=True)

# UNet Architecture in PyTorch

class EncoderBlock(nn.Module):
    def __init__(self, filters, rate, pooling=True):
        super(EncoderBlock, self).__init__()
        self.filters = filters
        self.rate = rate
        self.pooling = pooling
        
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=filters, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(in_channels=filters, out_channels=filters, kernel_size=3, padding=1)
        self.dropout = nn.Dropout(rate)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

    def forward(self, x):
        x = torch.relu(self.conv1(x))
        x = self.dropout(x)
        x = torch.relu(self.conv2(x))
        if self.pooling:
            return self.pool(x), x
        else:
            return x

class DecoderBlock(nn.Module):
    def __init__(self, filters, rate):
        super(DecoderBlock, self).__init__()
        self.filters = filters
        self.rate = rate
        self.upsample = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        self.conv1 = nn.Conv2d(in_channels=filters, out_channels=filters, kernel_size=3, padding=1)

    def forward(self, x, skip):
        x = self.upsample(x)
        x = torch.cat([x, skip], dim=1)  # Concatenate
        x = torch.relu(self.conv1(x))
        return x

class AttentionGate(nn.Module):
    def __init__(self, filters):
        super(AttentionGate, self).__init__()
        self.conv1 = nn.Conv2d(filters, filters, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(filters, filters, kernel_size=3, stride=2, padding=1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x, skip):
        x1 = torch.relu(self.conv1(x))
        x2 = torch.relu(self.conv2(skip))
        x = torch.add(x1, x2)
        return torch.mul(self.sigmoid(x), skip)

class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()
        self.encoder1 = EncoderBlock(32, 0.1)
        self.encoder2 = EncoderBlock(64, 0.1)
        self.encoder3 = EncoderBlock(128, 0.2)
        self.encoder4 = EncoderBlock(256, 0.2)
        
        self.center = EncoderBlock(512, 0.3, pooling=False)
        
        self.attention1 = AttentionGate(256)
        self.decoder1 = DecoderBlock(256, 0.2)
        
        self.attention2 = AttentionGate(128)
        self.decoder2 = DecoderBlock(128, 0.2)
        
        self.attention3 = AttentionGate(64)
        self.decoder3 = DecoderBlock(64, 0.1)
        
        self.attention4 = AttentionGate(32)
        self.decoder4 = DecoderBlock(32, 0.1)
        
        self.final_conv = nn.Conv2d(32, 1, kernel_size=1)
    
    def forward(self, x):
        p1, c1 = self.encoder1(x)
        p2, c2 = self.encoder2(p1)
        p3, c3 = self.encoder3(p2)
        p4, c4 = self.encoder4(p3)
        
        center = self.center(p4)
        
        a1 = self.attention1(center, c4)
        d1 = self.decoder1(center, a1)
        
        a2 = self.attention2(d1, c3)
        d2 = self.decoder2(d1, a2)
        
        a3 = self.attention3(d2, c2)
        d3 = self.decoder3(d2, a3)
        
        a4 = self.attention4(d3, c1)
        d4 = self.decoder4(d3, a4)
        
        return torch.sigmoid(self.final_conv(d4))

# Initialize Model
model = UNet()

# Loss and Optimizer
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training Loop
for epoch in range(20):
    model.train()
    running_loss = 0.0
    for images, masks in dataloader:
        images = images.permute(0, 3, 1, 2)  # Reshape for PyTorch (B, C, H, W)
        masks = masks.permute(0, 3, 1, 2)
        
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, masks)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()

    print(f'Epoch {epoch+1}, Loss: {running_loss/len(dataloader)}')

# Example Visualization of Prediction (after training)
image, mask = next(iter(dataloader))
model.eval()
with torch.no_grad():
    output = model(image.permute(0, 3, 1, 2))

output = output.squeeze(1)  # Remove channel dimension
plt.imshow(output[0].cpu().numpy(), cmap='gray')
plt.show()
# Out:
# Directory C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/ exists.
# Classes (Subdirectories): ['benign', 'malignant', 'normal']
# Contents of benign folder: ['benign (1).png', 'benign (1)_mask.png', 'benign (10).png', 'benign (10)_mask.png', 'benign (100).png']
# Contents of malignant folder: ['malignant (1).png', 'malignant (1)_mask.png', 'malignant (10).png', 'malignant (10)_mask.png', 'malignant (100).png']
# Contents of normal folder: ['normal (1).png', 'normal (1)_mask.png', 'normal (10).png', 'normal (10)_mask.png', 'normal (100).png']
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (1).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (10).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (100).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (101).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (102).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (103).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (104).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (105).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (106).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (107).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (108).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (109).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (11).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (110).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (111).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (112).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (113).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (114).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (115).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (116).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (117).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (118).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (119).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (12).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (120).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (121).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (122).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (123).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (124).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (125).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (126).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (127).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (128).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (129).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (13).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (130).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (131).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (132).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (133).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (134).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (135).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (136).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (137).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (138).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (139).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (14).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (140).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (141).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (142).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (143).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (144).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (145).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (146).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (147).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (148).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (149).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (15).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (150).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (151).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (152).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (153).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (154).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (155).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (156).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (157).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (158).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (159).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (16).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (160).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (161).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (162).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (163).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (164).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (165).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (166).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (167).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (168).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (169).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (17).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (170).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (171).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (172).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (173).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (174).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (175).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (176).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (177).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (178).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (179).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (18).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (180).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (181).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (182).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (183).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (184).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (185).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (186).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (187).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (188).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (189).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (19).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (190).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (191).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (192).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (193).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (194).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (195).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (196).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (197).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (198).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (199).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (2).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (20).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (200).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (201).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (202).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (203).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (204).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (205).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (206).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (207).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (208).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (209).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (21).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (210).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (211).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (212).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (213).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (214).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (215).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (216).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (217).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (218).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (219).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (22).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (220).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (221).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (222).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (223).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (224).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (225).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (226).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (227).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (228).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (229).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (23).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (230).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (231).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (232).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (233).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (234).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (235).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (236).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (237).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (238).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (239).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (24).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (240).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (241).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (242).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (243).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (244).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (245).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (246).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (247).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (248).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (249).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (25).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (250).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (251).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (252).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (253).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (254).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (255).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (256).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (257).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (258).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (259).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (26).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (260).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (261).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (262).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (263).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (264).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (265).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (266).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (267).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (268).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (269).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (27).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (270).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (271).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (272).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (273).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (274).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (275).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (276).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (277).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (278).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (279).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (28).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (280).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (281).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (282).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (283).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (284).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (285).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (286).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (287).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (288).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (289).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (29).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (290).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (291).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (292).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (293).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (294).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (295).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (296).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (297).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (298).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (299).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (3).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (30).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (300).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (301).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (302).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (303).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (304).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (305).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (306).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (307).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (308).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (309).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (31).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (310).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (311).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (312).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (313).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (314).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (315).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (316).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (317).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (318).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (319).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (32).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (320).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (321).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (322).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (323).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (324).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (325).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (326).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (327).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (328).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (329).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (33).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (330).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (331).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (332).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (333).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (334).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (335).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (336).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (337).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (338).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (339).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (34).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (340).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (341).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (342).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (343).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (344).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (345).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (346).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (347).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (348).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (349).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (35).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (350).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (351).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (352).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (353).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (354).png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\benign (355).png: name 'load_img' is not defined
# ...
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (3)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (30)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (31)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (32)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (33)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (34)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (35)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (36)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (37)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (38)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (39)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (4)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (40)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (41)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (42)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (43)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (44)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (45)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (46)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (47)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (48)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (49)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (5)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (50)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (51)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (52)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (53)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (54)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (55)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (56)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (57)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (58)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (59)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (6)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (60)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (61)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (62)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (63)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (64)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (65)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (66)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (67)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (68)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (69)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (7)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (70)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (71)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (72)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (73)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (74)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (75)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (76)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (77)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (78)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (79)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (8)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (80)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (81)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (82)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (83)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (84)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (85)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (86)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (87)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (88)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (89)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (9)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (90)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (91)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (92)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (93)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (94)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (95)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (96)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (97)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (98)_mask.png: name 'load_img' is not defined
# Error loading image C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/normal\normal (99)_mask.png: name 'load_img' is not defined
# Image Paths: ['C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\\benign (1).png', 'C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\\benign (10).png', 'C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\\benign (100).png', 'C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\\benign (101).png', 'C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\\benign (102).png']
# Mask Paths: ['C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\\benign (1)_mask.png', 'C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\\benign (10)_mask.png', 'C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\\benign (100)_mask.png', 'C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\\benign (101)_mask.png', 'C://Users/Muruganantham J/Documents/Research/Codes/BreastCancer_UNET/Dataset_BUSI_with_GT/benign\\benign (102)_mask.png']
# Number of samples in dataset: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 112
#     109 dataset = BreastCancerDataset(images, masks, transform=transform)
#     110 print(f"Number of samples in dataset: {len(dataset)}")
# --> 112 dataloader = DataLoader(dataset, batch_size=8, shuffle=True)
#     114 # UNet Architecture in PyTorch
#     116 class EncoderBlock(nn.Module):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\utils\data\dataloader.py:351, in DataLoader.__init__(self, dataset, batch_size, shuffle, sampler, batch_sampler, num_workers, collate_fn, pin_memory, drop_last, timeout, worker_init_fn, multiprocessing_context, generator, prefetch_factor, persistent_workers, pin_memory_device)
#     349 else:  # map-style
#     350     if shuffle:
# --> 351         sampler = RandomSampler(dataset, generator=generator)  # type: ignore[arg-type]
#     352     else:
#     353         sampler = SequentialSampler(dataset)  # type: ignore[arg-type]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\utils\data\sampler.py:144, in RandomSampler.__init__(self, data_source, replacement, num_samples, generator)
#     141     raise TypeError(f"replacement should be a boolean value, but got replacement={self.replacement}")
#     143 if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# --> 144     raise ValueError(f"num_samples should be a positive integer value, but got num_samples={self.num_samples}")
#
# ValueError: num_samples should be a positive integer value, but got num_samples=0
